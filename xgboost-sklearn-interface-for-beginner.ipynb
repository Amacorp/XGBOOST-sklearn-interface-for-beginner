# %% [markdown]
# # Don't forget to upvote📈 if you like👍🏻 it

# %% [markdown]
# XGBoost is one of the most popular machine learning algorithm these days. Regardless of the type of prediction task at hand; regression or classification.

# %% [markdown]
# Boosting is a sequential technique which works on the principle of an ensemble. It combines a set of weak learners and delivers improved prediction accuracy. At any instant t, the model outcomes are weighed based on the outcomes of previous instant t-1. The outcomes predicted correctly are given a lower weight and the ones miss-classified are weighted higher. Note that a weak learner is one which is slightly better than random guessing. For example, a decision tree whose predictions are slightly better than 50%.

# %% [markdown]
# # Import Necessary Libraries.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier

# %%
df = pd.read_csv('../input/mlcourse/telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# We will simply number the States, and make the international plan (international roaming), Voice mail plan (voice mail) and target Churn attributes binary.

# %%
state_enc = LabelEncoder()
df['State'] = state_enc.fit_transform(df['State'])
df['International plan'] = (df['International plan'] == 'Yes').astype('int')
df['Voice mail plan'] = (df['Voice mail plan'] == 'Yes').astype('int')
df['Churn'] = (df['Churn']).astype('int')

# %% [markdown]
# Divide the data into training and test samples with a ratio of 7: 3

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Churn', axis=1), df['Churn'],test_size=0.3, stratify=df['Churn'], random_state=17)

# %% [markdown]
# **Initializing parameters**
#
# binary classification ('objective': 'binary:logistic')
# limiting the depth of trees ('max_depth':3)
# we don't want extra output ('silent':1)
# we will perform 10 iterations of boosting
# the gradient descent step is quite large ('eta':1) - the algorithm will learn quickly and "aggressively" (better results will be obtained if you reduce the eta and increase the number of iterations)

# %%
params = {
    'objective': 'binary:logistic',
    'max_depth': 3,
    'learning_rate': 1.0,
    'n_estimators': 50
}

# %% [markdown]
# **Training of the classifier**
#
# Тут мы просто передаем слоавть параметров, данные и число итераций.

# %%
xgb_model = XGBClassifier(**params).fit(X_train, y_train)

# %% [markdown]
# Forecasts for the test sample

# %%
preds_prob = xgb_model.predict(X_test)

# %% [markdown]
# Let's calculate the percentage of correct algorithm responses in the test sample.

# %%
predicted_labels = preds_prob > 0.5
print("Accuracy and F1 on the test set are: {:.2} and {:.2}".format(
    round(accuracy_score(y_test, predicted_labels), 3),
    round(f1_score(y_test, predicted_labels), 3)))
# Out:
# Accuracy and F1 on the test set are: 0.94 and 0.75
